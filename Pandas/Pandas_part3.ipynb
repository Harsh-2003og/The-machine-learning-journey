# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Name"][4:11]
# Out:
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# Name: Name, dtype: object

# %%
l = ['a', 'b', 'c', 'd', 'e', 'f']
pd.Series(l)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# 5    f
# dtype: object

# %%
df['Name'][2:7]
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# 5                                Moran, Mr. James
# 6                         McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %%
pd.Series(list(df['Name'][2:7]), index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# d                                Moran, Mr. James
# e                         McCarthy, Mr. Timothy J
# dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop("Survived", axis = 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 df.drop("Survived", axis = 1, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
df
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
df.drop(3, inplace=True) # Inplace is used to remove the element parmanently from the DataFrame.

# %%
df
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# 5         3                                   Moran, Mr. James    male   NaN
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
df.set_index("Name", inplace=True)

# %%
df #Inplace?
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# ...

# %%
df.loc["Heikkinen, Miss. Laina"]
# Out:
# Pclass                     3
# Sex                   female
# Age                     26.0
# SibSp                      0
# Parch                      0
# Ticket      STON/O2. 3101282
# Fare                   7.925
# Cabin                    NaN
# Embarked                   S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
df.iloc[2]
# Out:
# Pclass                     3
# Sex                   female
# Age                     26.0
# SibSp                      0
# Parch                      0
# Ticket      STON/O2. 3101282
# Fare                   7.925
# Cabin                    NaN
# Embarked                   S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#                                                 Name  Pclass     Sex   Age  \
# 0                            Braund, Mr. Owen Harris       3    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female  38.0
# 2                             Heikkinen, Miss. Laina       3  female  26.0
# 3                           Allen, Mr. William Henry       3    male  35.0
# 4                                   Moran, Mr. James       3    male   NaN
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0      0            373450   8.0500   NaN        S
# 4      0      0            330877   8.4583   NaN        Q

# %%
df1 = pd.read_csv(r"D:\Python\Notebook\taxonomy.csv.xls")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1.fillna("Filled")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency    Filled                Filled
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.groupby("Survived").mean()
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408

# %%
df.groupby("Survived").sum()
# Out:
#           PassengerId  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0              245412    1390  12985.50    304    181  12142.7199
# 1              151974     667   8219.67    162    159  16551.2294

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.groupby("Sex").sum()
# Out:
#         PassengerId  Survived  Pclass       Age  SibSp  Parch        Fare  \
# Sex
# female       135343       314     678   7286.00    218    204  13966.6628
# male         262043       577    1379  13919.17    248    136  14727.2865
#
#             Fare_inr  Name_len
# Sex
# female  1.229066e+06     10239
# male    1.296001e+06     13787

# %%
df.groupby("Sex").mean()["Age"]
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
df.groupby("Pclass").mean()
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222       1.0  38.233441  0.416667  0.356481  84.154687
# 2        445.956522       1.0  29.877630  0.402174  0.380435  20.662183
# 3        439.154786       1.0  25.140620  0.615071  0.393075  13.675550

# %%
df3 = df.groupby("Pclass").sum()
df3
# Out:
#         PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1             99705       216  7111.42     90     77  18177.4125
# 2             82056       184  5168.83     74     70   3801.8417
# 3            215625       491  8924.92    302    193   6714.6951

# %%
df3.T # Transpose of a Dataset.
# Out:
# Pclass                1           2            3
# PassengerId  99705.0000  82056.0000  215625.0000
# Survived       216.0000    184.0000     491.0000
# Age           7111.4200   5168.8300    8924.9200
# SibSp           90.0000     74.0000     302.0000
# Parch           77.0000     70.0000     193.0000
# Fare         18177.4125   3801.8417    6714.6951

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df4 = df[['Name', 'Sex', 'Age']][0:6]
df4
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN

# %%
df5 = df[['Name', 'Survived', 'Pclass']][6:13]
df5
# Out:
#                                                  Name  Survived  Pclass
# 6                             McCarthy, Mr. Timothy J         1       1
# 7                      Palsson, Master. Gosta Leonard         1       3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                 Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 10                    Sandstrom, Miss. Marguerite Rut         1       3
# 11                           Bonnell, Miss. Elizabeth         1       1
# 12                     Saundercock, Mr. William Henry         1       3

# %%
pd.concat([df4, df5]) # Vertical Concatination
# Out:
#                                                  Name     Sex   Age  Survived  \
# 0                             Braund, Mr. Owen Harris    male  22.0       NaN
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       NaN
# 2                              Heikkinen, Miss. Laina  female  26.0       NaN
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       NaN
# 4                            Allen, Mr. William Henry    male  35.0       NaN
# 5                                    Moran, Mr. James    male   NaN       NaN
# 6                             McCarthy, Mr. Timothy J     NaN   NaN       1.0
# 7                      Palsson, Master. Gosta Leonard     NaN   NaN       1.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     NaN   NaN       1.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)     NaN   NaN       1.0
# 10                    Sandstrom, Miss. Marguerite Rut     NaN   NaN       1.0
# ...

# %%
df5 = pd.concat([df4, df5], axis=1) # Horizontal concatination
df5
# Out:
#                                                  Name     Sex   Age  \
# 0                             Braund, Mr. Owen Harris    male  22.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss. Laina  female  26.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                            Allen, Mr. William Henry    male  35.0
# 5                                    Moran, Mr. James    male   NaN
# 6                                                 NaN     NaN   NaN
# 7                                                 NaN     NaN   NaN
# 8                                                 NaN     NaN   NaN
# 9                                                 NaN     NaN   NaN
# 10                                                NaN     NaN   NaN
# 11                                                NaN     NaN   NaN
# 12                                                NaN     NaN   NaN
#
# ...

# %%
df5.fillna("Filled lol")
# Out:
#                                                  Name         Sex         Age  \
# 0                             Braund, Mr. Owen Harris        male        22.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...      female        38.0
# 2                              Heikkinen, Miss. Laina      female        26.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)      female        35.0
# 4                            Allen, Mr. William Henry        male        35.0
# 5                                    Moran, Mr. James        male  Filled lol
# 6                                          Filled lol  Filled lol  Filled lol
# 7                                          Filled lol  Filled lol  Filled lol
# 8                                          Filled lol  Filled lol  Filled lol
# 9                                          Filled lol  Filled lol  Filled lol
# 10                                         Filled lol  Filled lol  Filled lol
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df["Fare_inr"] = df["Fare"].apply(lambda x: x*88)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         1       3
# 5            6         1       3
# 6            7         1       1
# 7            8         1       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df["Name_len"] = df['Name'].apply(len)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Fare_inr  Name_len
# 0      0         A/5 21171   7.2500   NaN        S   638.0000        23
# 1      0          PC 17599  71.2833   C85        C  6272.9304        51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   697.4000        22
# ...

# %%
def create_flag(x):
    if x<=10:
        return "Cheap"
    elif x >= 10 and x < 20 :
        return "Middle class"
    else :
        return "Rich Person"

# %%
df['Fare_flag'] = df["Fare"].apply(create_flag)
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         1       3
# 5            6         1       3
# 6            7         1       1
# 7            8         1       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.groupby("Fare_flag").sum()
# Out:
#               PassengerId  Survived  Pclass       Age  SibSp  Parch  \
# Fare_flag
# Cheap              151593       336     990   6644.92     27     10
# Middle class        77732       179     439   4308.00     68     53
# Rich Person        168061       376     628  10252.25    371    277
#
#                     Fare      Fare_inr  Name_len
# Fare_flag
# Cheap          2525.0203  2.222018e+05      7835
# Middle class   2484.4499  2.186316e+05      4928
# Rich Person   23684.4791  2.084234e+06     11263
